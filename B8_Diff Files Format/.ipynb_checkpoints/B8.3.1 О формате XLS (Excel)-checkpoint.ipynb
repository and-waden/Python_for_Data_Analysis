# %% [markdown]
# #### B8.3.1 О формате XLS (Excel)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_excel('Fig3-1.xls', header=None)

# %%
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 859                                            2018.79  174.056  NaN
# 860                                            2018.87  174.439  NaN
# 861                                            2018.96  174.659  NaN
# 862                                            2019.04  174.016  NaN
# 863                                                NaN      NaN  NaN
#
#            3                                                  4    5    6   \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data_file = pd.ExcelFile('./Fig3-1.xls')  
data = pd.read_excel(data_file, header=None)

# %%
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 859                                            2018.79  174.056  NaN
# 860                                            2018.87  174.439  NaN
# 861                                            2018.96  174.659  NaN
# 862                                            2019.04  174.016  NaN
# 863                                                NaN      NaN  NaN
#
#            3                                                  4    5    6   \
# ...

# %%
with pd.ExcelFile('./Fig3-1.xls') as xls:  
    data['Fig 3.1'] = pd.read_excel(xls, "Sheet1", na_values=['NA'])  
    data['Data'] = pd.read_excel(xls, "Sheet2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     473         try:
# --> 474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
#
# ValueError: 'Sheet1' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-27-37a4a63ae241> in <module>
#       1 with pd.ExcelFile('./Fig3-1.xls') as xls:
# ----> 2     data['Fig 3.1'] = pd.read_excel(xls, "Sheet1", na_values=['NA'])
#       3     data['Data'] = pd.read_excel(xls, "Sheet2")
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
with pd.ExcelFile('./Fig3-1.xls') as xls:  
    data['Sheet1'] = pd.read_excel(xls, 'Sheet1')  
    data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     473         try:
# --> 474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
#
# ValueError: 'Sheet1' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-24-bc07bbf49377> in <module>
#       1 with pd.ExcelFile('./Fig3-1.xls') as xls:
# ----> 2     data['Sheet1'] = pd.read_excel(xls, 'Sheet1')
#       3     data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
data = pd.read_excel('http://www.econ.yale.edu/~shiller/data/Fig3-1.xls', header=None)
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 866                                            2019.37  175.147  NaN
# 867                                            2019.46  176.131  NaN
# 868                                            2019.54  176.456  NaN
# 869                                            2019.62  176.767  NaN
# 870                                            2019.71  176.842  NaN
#
#            3                                                  4    5    6   \
# ...

# %% [markdown]
# Если мы посмотрим на то, как выглядит файл, то увидим, что первые две строчки — пустые, и при чтении файла их желательно пропустить. Для этого можно передать в функцию read_excel дополнительный параметр — skiprows. В качестве значения параметра укажем количество строк, которые надо пропустить при чтении:

# %% [markdown]
# #### Задание 1
# Сколько строк нужно пропустить в начале, чтобы в первой строке получить номер и дату накладной?

# %%
data = pd.read_excel("./nakladnaya.xls", header=None, skiprows=2)

# %% [markdown]
# #### Задание 2
# Можно заметить, что многие строки полностью состоят из пропусков. Используйте изученный ранее метод pandas, чтобы убрать все такие строки. Запишите ниже, сколько строк осталось.
# Чтобы убирать только те строки, в которых все значения являются пропусками, нужно использовать параметр how и передавать в него значение all.

# %%
# data = pd.read_excel("./nakladnaya.xls", header=None, skiprows=2)
# data.dropna(axis=1, how='all', inplace=True)
# data.info()

# %%
data = pd.read_excel("./nakladnaya.xls", header=None, skiprows=2)
# data.drop(how = "all", inplace = True, axis = 0)
# data.info()

data.dropna(axis=1, how='all')
# Out:
#                                    1   \
# 0                                 NaN
# 1                                 NaN
# 2                   Грузоотправитель:
# 3                                 NaN
# 4                    Грузополучатель:
# 5                                 NaN
# 6   Основание для отпуска: Договор №
# 7                                 NaN
# 8                                 NaN
# 9                                   №
# 10                                п/п
# 11                                  1
# 12                                  2
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# ...

# %% [markdown]
# #### Задание 3
# Для начала, давайте узнаем номер накладной.
#
# Какой код поможет нам сделать это?

# %%
data.iloc[0, 4][2:9]
# Out:
# '5764809'

# %% [markdown]
# #### Задание 4
# В данных все-таки есть небольшая таблица. Давайте узнаем, сколько в ней признаков.
#
# Напишите ниже, сколько столбцов, содержащих значимые данные, содержится в таблице.
# Например, 23. Не забудьте про столбец с номером товар

# %%
6

# %% [markdown]
# #### Задание 5
# Теперь финальная часть - вытащим эту таблицу.
#
# Выберите те варианты, которые позволят нам получить эту таблицу.
# Не забудьте избавиться от пропусков. Заголовок таблицы нам тоже не нужен.

# %%
data.iloc[6:8, [1, 2, 6, 9, 11, 12]]
# Out:
#                                   1    2    6    9    11   12
# 6  Основание для отпуска: Договор №   NaN  NaN  NaN  NaN  NaN
# 7                                NaN  NaN  NaN  NaN  NaN  NaN

# %%
data.iloc[6:8, :].dropna(axis=1, how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [6, 7]

# %%
data.iloc[6:8, :].dropna(axis=1, how='all')
# Out:
#                                    1    4                      5
# 6  Основание для отпуска: Договор №    86  от "02"апреля 2018 г.
# 7                                NaN  NaN                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
# 0     0 non-null float64
# 1     7 non-null object
# 2     10 non-null object
# 3     8 non-null object
# 4     2 non-null object
# 5     1 non-null object
# 6     3 non-null object
# 7     0 non-null float64
# 8     3 non-null object
# 9     3 non-null object
# 10    0 non-null float64
# 11    7 non-null object
# 12    4 non-null object
# dtypes: float64(3), object(10)
# memory usage: 2.8+ KB
